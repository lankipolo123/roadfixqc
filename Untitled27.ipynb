# %% [markdown]
# <a href="https://colab.research.google.com/github/lankipolo123/roadfixqc/blob/main/Untitled27.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ================================
# 1. INSTALL
# ================================
# !pip install ultralytics -q

# ================================
# 2. IMPORTS
# ================================
from ultralytics import YOLO

# ================================
# 3. LOAD YOUR MODEL
# ================================
from google.colab import files

uploaded = files.upload()  # upload your best.pt here

# ================================
# 4. EXPORT TO TFLITE
# ================================
model = YOLO("best.pt")
model.export(
    format="tflite",
    int8=True,
    imgsz=640
)

print("✅ EXPORT DONE")

# ================================
# 5. DOWNLOAD
# ================================
files.download("best_saved_model/best_float32.tflite")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 83.3 MB/s eta 0:00:00
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
#      <input type="file" id="files-38d620cb-ca1a-4340-a1ff-1e6081830fc4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-38d620cb-ca1a-4340-a1ff-1e6081830fc4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# ...
