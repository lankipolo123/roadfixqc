# %% [markdown]
# <a href="https://colab.research.google.com/github/lankipolo123/roadfixqc/blob/main/convert_to_tflite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install ultralytics
# !pip install -q ultralytics

# Upload file
from google.colab import files
uploaded = files.upload()

# Convert
from ultralytics import YOLO
pt_file = list(uploaded.keys())[0]
model = YOLO(pt_file)
model.export(format='tflite')

# Download
import os
for root, dirs, filenames in os.walk('.'):
    for f in filenames:
        if f.endswith('_float32.tflite'):
            files.download(os.path.join(root, f))
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 17.5 MB/s eta 0:00:00
#      <input type="file" id="files-e1aaa4df-c4ff-417c-b29f-fc19c9bf2f7e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e1aaa4df-c4ff-417c-b29f-fc19c9bf2f7e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# Install ultralytics
# !pip install -q ultralytics

# Upload file
from google.colab import files
uploaded = files.upload()

# Convert
from ultralytics import YOLO
pt_file = list(uploaded.keys())[0]
model = YOLO(pt_file)
model.export(format='tflite')

# Download
import os
for root, dirs, filenames in os.walk('.'):
    for f in filenames:
        if f.endswith('_float32.tflite'):
            files.download(os.path.join(root, f))
# Out:
#      <input type="file" id="files-1722422e-47ed-4dd8-9390-0d9091ebd98a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1722422e-47ed-4dd8-9390-0d9091ebd98a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
